# %% [markdown]
# ## Project 1: Exploratory Data Analysis - Gapminder dataset

# %% [markdown]
# The Gapminder dataset provides population data from 1952 to 2007 (at 5 year Intervals) for several countries around the world.Compares the populations of the European countries France, United Kingdom, Italy, Germany and Spain over this period using a line chart. Make appropriate modifications to the chart title, axis titles, legends, figure size, font size, colors etc to make the chart readable and visually appealing - #Line Chart

# %%
import pandas as pd
import numpy as np

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
df_gapminder = pd.read_csv(r"C:\Users\gaura\OneDrive\Documents\GitHub\MachineLearning2026_Gaurav\Dataset\gapminderDataFiveYear.csv")
df_gapminder.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
countries = ["France", "United Kingdom", "Italy", "Germany", "Spain"]
eu_df = df_gapminder[df_gapminder["country"].isin(countries)]

sns.set_style("darkgrid")
plt.figure(figsize=(12, 6))

sns.lineplot(
    data=eu_df,
    x="year",
    y="pop",
    hue="country",
    marker="o",
    linewidth=2
)

plt.title("Population Comparison of Major European Countries (1952–2007)", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Population", fontsize=14)
plt.legend(title="Country", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Project 2: Exploratory Data Analysis - Diamonds dataset

# %% [markdown]
# diamond.csv points to a CSV file containing various attributes like carat, cut, color, clarity, price etc. For over 53,000 diamonds, Visulize the relationip between the carat (size of diamond) and price using a scatter plot. Instead of using the entire dataset for this visualization. Just pick the diamonds with a clarify "SI2" and color "E". Use the value of the "cut" column to color the dots in the scatter plot. Make appropriate modifications to the chart title, axis title, legend, figure size, font size, colors etc. to make the chart readable and visually appealing, -# Scatterplot

# %%
diamond_df= pd.read_csv(r"C:\Users\gaura\OneDrive\Documents\GitHub\MachineLearning2026_Gaurav\Dataset\diamonds.csv")
diamond_df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
filtered_df = diamond_df[
    (diamond_df["clarity"] == "SI2") &
    (diamond_df["color"] == "E")
]

sns.set_style("darkgrid")
plt.figure(figsize=(12, 7))

sns.scatterplot(
    data=filtered_df,
    x="carat",
    y="price",
    hue="cut",
    palette="Set2",
    alpha=0.7,
    s=70
)

plt.title(
    "Carat vs Price for Diamonds (Clarity: SI2, Color: E)",
    fontsize=16
)
plt.xlabel("Carat (Diamond Size)", fontsize=14)
plt.ylabel("Price (USD)", fontsize=14)
plt.legend(title="Cut", fontsize=11, title_fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Project 3: Exploratory Data Analysis - Planets dataset

# %% [markdown]
# The Planet dataset contains details about the 1000+ extrasolar planets discovered up to 2014. Visualize the distribution of the masses of the planets (exptessed as a multiple of the mass of Jupiter), using a histogram and a box plot. Make appopriate modifications to the chart title, axis title, legend, figure size, font size, colors etc, to make the chart readable and visually appealing, -# Histogram adn Box Plot
